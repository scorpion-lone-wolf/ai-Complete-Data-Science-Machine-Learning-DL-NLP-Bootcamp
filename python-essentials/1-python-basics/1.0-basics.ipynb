# %% [markdown]
# ### Indentation in Python
#
# Indentation in Python is used to define the structure and hierarchy of the code.
#
# Unlike many other programming languages that use braces `{}` to delimit blocks of code, Python uses indentation to determine the grouping of statements.
#
# This means that all the statements within a block must be indented at the same level.

# %%
## Indentation
## Python uses indentation to define block of code. Consistent use of spaces(commonly 4) or a tab is required.
age=32
if age>30:
    print(age)
print(age)
# Out:
# 32
# 32

# %%
## Line Continuation in python
## uses a backslash (\) to continue a statement to the next line
total=1+2+3+4+\
5+6
print("Total is ", total)
# Out:
# Total is  21

# %%
## Variable assignment
name='rahul' # name is a string
age=28 # age is a integer
print(f'Type of name is {type(name)} and Type of age is {type(age)}')
# Out:
# Type of name is <class 'str'> and Type of age is <class 'int'>

# %%
## Syntax Error
# name 'b' is not defined
# a=b

# %%
## Code Example of indentation
if True:
    print("This is Example of indentation")
    if False:
        print("This will not print")
    print("This will be printed")
print("This is outside of if block")
# Out:
# This is Example of indentation
# This will be printed
# This is outside of if block
