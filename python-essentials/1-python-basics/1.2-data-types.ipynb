# %%
## int data types
age=20
type(age)
# Out:
# int

# %%
## float data types
height=5.4
type(height)
# Out:
# float

# %%
## str data types
name='rahul'
type(name)
# Out:
# str

# %%
## bool data types
is_male=True
type(is_male)
# Out:
# bool

# %%
# concatination

# Incorrect way
# print("hello" + 5)

# Correct way
print("hello"+str(5))
# Out:
# hello5
