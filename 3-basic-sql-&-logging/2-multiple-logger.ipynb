# %%
import logging

# %%
logging.basicConfig(level=logging.DEBUG)
app_logger = logging.getLogger("app")
db_logger = logging.getLogger("db")

app_logger.setLevel(logging.DEBUG)
db_logger.setLevel(logging.INFO)

app_logger.debug("This is a debug message from app logger")
db_logger.info("This is a info message from db logger")
# Out:
# DEBUG:app:This is a debug message from app logger
# INFO:db:This is a info message from db logger
