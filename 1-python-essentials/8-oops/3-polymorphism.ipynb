# %% [markdown]
# ### Polymorphism in Python is the ability of a function, method, or object to take on multiple forms.
# It allows you to use a single interface to represent different types of data or objects.
#
# Polymorphism is a key feature of object-oriented programming (OOP) and can be achieved through method overriding and operator overloading.

# %% [markdown]
# ###  Method Overriding:
# Method overriding occurs when a child class provides a specific implementation of a method that is already defined in its parent class.
#
# The child class's method will be called instead of the parent class's method when the method is invoked on an instance of the child class.

# %%
class Parent:
    def greet(self):
        return "Hello from the Parent class!"
class Child(Parent):
    def greet(self):
        return "Hello from the Child class!"

# *Function that demonstrates polymorphism by accepting an object of the Parent class and calling the greet method
def greet(obj: Parent):
    return obj.greet()

parent_instance = Parent()
child_instance = Child()
print(greet(parent_instance))  # Output: Hello from the Parent class!
print(greet(child_instance))   # Output: Hello from the Child class!
# Out:
# Hello from the Parent class!
# Hello from the Child class!

# %%
# *Polymorphism with Functions and Methods
from abc import ABC, abstractmethod
# This is an abstract class
# It means we cannot create an object of this class. We can only create an object of the child class that inherits from this class.
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Rectangele(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height
    def area(self):
        return self.width * self.height

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return 3.14 * (self.radius ** 2)

def calculate_area(shape: Shape):
    return shape.area()

# %%
# *trying to create an object of the abstract class will raise an error
try :
    shape = Shape()  # This will raise an error: TypeError
except TypeError as e:
    print("ERROR :",e)

rectangel1 = Rectangele(5, 10)
circle1 = Circle(7)
print("Area of Rectangle:", calculate_area(rectangel1))  # Output: Area of Rectangle: 50
print("Area of Circle:", calculate_area(circle1))        # Output: Area of Circle:
# Out:
# ERROR : Can't instantiate abstract class Shape with abstract method area
# Area of Rectangle: 50
# Area of Circle: 153.86
